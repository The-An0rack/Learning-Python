# %% [markdown]
# <a href="https://colab.research.google.com/github/The-An0rack/Learning-Python/blob/main/Day003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Day 3: Conditional Statements and Logical Operators**
#
# ###**Comparision Operators**
# * `>` : Greater Than
# * `>=` : Greater Than or equals to
# * `<` : Lesser Than
# * `<=` : Lesser Than or Equals to
# * `==` : Is equals to
# * `!=` : Not equals to
#
# ###**If Else Statements**
# *In the codition 0 is treated as false and non zero value is treated as true*

# %%
print('Welcome to the rollercoaster')
height = int(input('What is your height in cm?'))

if height >= 120:
  print('You can ride the rollercoaster.')
else:
  print('You, you have to grow taller before you can ride.')
# Out:
# Welcome to the rollercoaster
# What is your height in cm?121
# You can ride the rollercoaster.

# %% [markdown]
# ###**Nested If Statements**

# %%
age = int(input('What is your age? '))
height = int(input('What is your height in cm?'))

if height >= 120:
  if (age < 12):
    print('Please pay $5')
  elif age <= 18:
    print('Please pay $7')
  else:
    print('Please pay $12')
else:
  print('Sorry, you have to grow taller before you can ride.')
# Out:
# What is your age? 12
# What is your height in cm?123
# Please pay $7

# %% [markdown]
# ####**Code to check if a year is leap year or not**
#
# ![Leap Year.png](data:image/png;base64,...)

# %%
year = int(input("Which year do you want to check? "))

if year%4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print('Leap Year.')
    else:
      print('Not Leap Year.')
  else:
    print('Leap Year.')
else:
  print('Not Leap Year.')
# Out:
# Which year do you want to check? 2012
# Leap Year.

# %% [markdown]
# ###**Multiple If Statements in Succession**

# %%
age = int(input('What is your age? '))
height = int(input('What is your height in cm?'))

ticket_price = 0

if height >= 120:
  if (age < 12):
    ticket_price = 5
  elif age <= 18:
    ticket_price = 7
  else:
    ticket_price = 12

  wants_photo = input('Do you need a photo? (Y/N) ')
  if wants_photo == 'Y':
    ticket_price += 3

  print(f'Please Pay ${ticket_price}')
else:
  print('Sorry, you have to grow taller before you can ride.')
# Out:
# What is your age? 21
# What is your height in cm?150
# Do you need a photo? (Y/N) Y
# Please Pay $15

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L ")
add_pepperoni = input("Do you want pepperoni? Y or N ")
extra_cheese = input("Do you want extra cheese? Y or N ")

total_bill = 0

if size == 'S':
  total_bill += 15
elif size == 'M':
  total_bill += 20
else:
  total_bill += 25

if add_pepperoni == 'Y':
  if size == 'S':
    total_bill += 2
  else:
    total_bill += 3

if extra_cheese == 'Y':
  total_bill += 1

print(f'Your final bill is ${total_bill}')
# Out:
# Welcome to Python Pizza Deliveries!
# What size pizza do you want? S, M, or L S
# Do you want pepperoni? Y or N Y
# Do you want extra cheese? Y or N Y
# Your final bill is $18

# %% [markdown]
# ###**Logical Operators**
# 1. **AND**: `a and b` to be true both of the conditions must be true, else results false.
# 2. **OR**: `a or b` to be true either or both of the conditions must be true, else false.
# 3. **NOT**: `not a` to be true condition must be false.

# %%
age = int(input('What is your age? '))
height = int(input('What is your height in cm?'))

if height >= 120:
  if (age < 12):
    print('Please pay $5')
  elif age <= 18:
    print('Please pay $7')
  elif age >= 45 and age <= 55:
    print('Everything is going to be ok. Have a free ride on us!')
  else:
    print('Please pay $12')
else:
  print('Sorry, you have to grow taller before you can ride.')
# Out:
# What is your age? 47
# What is your height in cm?150
# Everything is going to be ok. Have a free ride on us!

# %% [markdown]
# ###Mini Project: **Love Calculator**
#
# * The `lower()` function changes all the letters in a string to lowercase.
# * The `count()` function will give you the number of times a letter occurs in a string.

# %%
print("Welcome to the Love Calculator!")
name1 = input("What is your name? \n").lower()
name2 = input("What is their name? \n").lower()

t_count = name1.count('t') + name2.count('t')
r_count = name1.count('r') + name2.count('r')
u_count = name1.count('u') + name2.count('u')
e_count = name1.count('e') + name2.count('e')

l_count = name1.count('l') + name2.count('l')
o_count = name1.count('o') + name2.count('o')
v_count = name1.count('v') + name2.count('v')
e_count = name1.count('e') + name2.count('e')

love_score = (t_count + r_count + u_count + e_count)*10 + (l_count + o_count + v_count + e_count)

if love_score < 10 or love_score > 90:
  print(f'Your score is {love_score}, you go together like coke and mentos.')
elif love_score >= 40 and love_score <= 50:
  print(f'Your score is {love_score}, you are alright together.')
else:
  print(f'Your score is {love_score}.')
# Out:
# Welcome to the Love Calculator!
# What is your name?
# Nobita
# What is their name?
# Shizuka
# Your score is 21

# %% [markdown]
# ### Mini Project: **Treasure Island**

# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.")

choice = input('You\'re at a crossroad, where do you want to go? Type "left" or "right"').lower()

if choice == 'left':
  choice = input('You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for boat. Type "swim" to swim across').lower()

  if choice == "wait":
    choice = input('You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which one do you choose?').lower()

    if choice == 'red':
      print('It\'s a room full of fire. GAME OVER!!!')
    elif choice == 'yellow':
      print('you\'ve found the treasure. CONGRATULATIONS!!!')
    elif choice == 'blue':
      print('You\'ve entered room of beast. GAME OVER!!!')
    else:
      print('GAME OVER!!!')
  else:
    print('You got attacked by a crocodile. GAME OVER!!!')
else:
  print('You fell into a hole. GAME OVER!!!')
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
